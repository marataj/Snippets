# %%
import pandas as pd

# %%
prestige=pd.read_csv(r"d:\temp\Prestige.csv",index_col="name")

# %%
prestige.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
prestige.loc["chemists","type"]="scientist"

# %%
prestige.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      73.5    2111  scientist

# %%
isScientist=prestige["type"]=="scientist"

# %%
isScientist.head()
# Out:
# name
# gov.administrators     False
# general.managers       False
# accountants            False
# purchasing.officers    False
# chemists                True
# Name: type, dtype: bool

# %%
prestige.loc[isScientist,"prestige"]=90

# %%
prestige.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      90.0    2111  scientist

# %%
prestige.loc[isScientist,"income"]*=1.5

# %%
prestige.head()
# Out:
#                      education   income  women  prestige  census       type  \
# name
# gov.administrators       13.11  12351.0  11.16      68.8    1113       prof
# general.managers         12.26  25879.0   4.02      69.1    1130       prof
# accountants              12.77   9271.0  15.70      63.4    1171       prof
# purchasing.officers      11.42   8865.0   9.11      56.8    1175       prof
# chemists                 14.62  12604.5  11.68      90.0    2111  scientist
#
#                      Prestige
# name
# gov.administrators        NaN
# general.managers          NaN
# accountants               NaN
# purchasing.officers       NaN
# chemists                 90.0

# %%
dict={"education"	income	women	prestige	census	type"Prestige"}
# Out:
#   File "<ipython-input-2-0d78c8d50866>", line 1
#     dict={"education"	income	women	prestige	census	type"Prestige"}
#                      	^
# SyntaxError: invalid syntax
